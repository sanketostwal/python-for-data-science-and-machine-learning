# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Sanket\\python-for-data-science-and-machine-learning'

# %%
df = pd.read_csv('example')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('myoutput')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_csv('myoutput')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_csv('myoutput',index=False)

# %%
pd.read_csv('myoutput')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel('myoutputexcel2.xlsx',sheet_name='Data')

# %%
pd.read_excel('myoutputexcel2.xlsx',sheet_name='Data')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
data = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
data
# Out:
# [                                             Bank Name                City  \
#  0                     City National Bank of New Jersey              Newark
#  1                                        Resolute Bank              Maumee
#  2                                Louisa Community Bank              Louisa
#  3                                 The Enloe State Bank              Cooper
#  4                  Washington Federal Bank for Savings             Chicago
#  5      The Farmers and Merchants State Bank of Argonia             Argonia
#  6                                  Fayette County Bank          Saint Elmo
#  7    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
#  8                                       First NBC Bank         New Orleans
#  9                                        Proficio Bank  Cottonwood Heights
#  10                       Seaway Bank and Trust Company             Chicago
# ...
